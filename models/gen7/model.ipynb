# %% [markdown]
# # Import Libraries

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"   # Prevent incompatible gpu

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Exploratory Data Analysis

# %%
ROOT = "../../datasets/"
SEED = 88
IMG_SIZE = (224, 224)    # load at original size first
BATCH_SIZE = 256
LABEL_MODE = "categorical" # one‑hot labels straight away

classes=["broccoli", "cauliflower", "unknown"]
splits=["test", "train", "validate"]

def load_split(split):
    dataset=tf.keras.preprocessing.image_dataset_from_directory(ROOT+split,
        seed        = SEED,
        image_size  = IMG_SIZE,
        batch_size  = BATCH_SIZE,
        label_mode  = LABEL_MODE)
    return dataset

train_ds_pre = load_split("train")
val_ds_pre = load_split("validate")
test_ds_pre = load_split("test")
# Out:
# Found 6860 files belonging to 3 classes.
# Found 841 files belonging to 3 classes.
# Found 842 files belonging to 3 classes.

# %%
def count_images(split):
    return {cls: len(os.listdir(f"{ROOT}{split}/{cls}/"))
            for cls in classes}

df_counts = pd.DataFrame({s: count_images(s) for s in splits})

table_df = df_counts.T
table_df["splits total"] = table_df.sum(1)
table_df.loc["img total"] = table_df.sum(0)

display(table_df)  # Jupyter table

ax = df_counts.plot.bar(stacked=True, figsize=(8,3))
ax.set_title("Class distribution across splits")
ax.set_ylabel("Image count")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
#            broccoli  cauliflower  unknown  splits total
# test            311          299      232           842
# train          2595         2407     1858          6860
# validate        311          298      232           841
# img total      3217         3004     2322          8543

# %%
plt.figure(figsize=(6,6))
for images, labels in train_ds_pre.take(1):
    for i in range(16):
        ax = plt.subplot(4,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(classes[np.argmax(labels[i])], fontsize=7)
        plt.axis("off")
plt.suptitle("Random train samples", y=0.92)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
TARGET_SIZE = 100

resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(TARGET_SIZE, TARGET_SIZE),
    layers.Rescaling(1./255)
])

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3),
    layers.RandomTranslation(0.2, 0.2),
    layers.RandomZoom((0.3), 0.3),
    layers.RandomBrightness(0.2, value_range=(0, 1))
])

AUTOTUNE = tf.data.AUTOTUNE

def prepare(ds, shuffle=False, augment=False):
    # Resize and rescale all datasets.
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y), 
                num_parallel_calls=AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(1000)

    # Use data augmentation only on the training set.
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    # Use buffered prefetching on all datasets.
    return ds.prefetch(buffer_size=AUTOTUNE)

train_ds = prepare(train_ds_pre, shuffle=True, augment=True)
val_ds = prepare(val_ds_pre)
test_ds = prepare(test_ds_pre)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %%
plt.figure(figsize=(3,3))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow((images[i].numpy() * 255).astype("uint8"))
        plt.title(classes[np.argmax(labels[i])], fontsize=7)
        plt.axis("off")

plt.suptitle("Random train samples", y=0.92)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model building

# %%
num_classes = 3

model = keras.Sequential()

model.add(Conv2D(32, (3, 3), padding='same', activation="relu",
                 input_shape=(TARGET_SIZE, TARGET_SIZE,3)))

model.add(layers.Conv2D(64, (3,3), padding="same", activation="relu"))
model.add(layers.MaxPool2D((2,2)))   # 50→25
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(128, (3,3), padding="same", activation="relu"))

model.add(layers.Conv2D(256, (3,3), padding="same", activation="relu"))
model.add(layers.MaxPool2D((2,2)))   # 12→6
model.add(layers.Dropout(0.3))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(64, activation="relu"))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(64, activation="relu"))
model.add(layers.Dense(num_classes, activation="softmax"))

model.summary()

Optimizer = optimizers.Adam(0.001)
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=Optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 64)       0
#  )
#
#  dropout (Dropout)           (None, 50, 50, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 256)       295168
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 25, 25, 256)       0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 409,219
# Trainable params: 409,219
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(
    train_ds,
    epochs=40,
    verbose=1,
    validation_data = val_ds,
    callbacks=[early_stop]
)

score = model.evaluate(test_ds, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


model.save_weights('model_weights.hdf5')
tf.keras.models.save_model(model,'model.hdf5')
# Out:
# Epoch 1/40
# 27/27 [==============================] - 365s 10s/step - loss: 1.0829 - accuracy: 0.3882 - val_loss: 1.0343 - val_accuracy: 0.4114
# Epoch 2/40
# 27/27 [==============================] - 347s 10s/step - loss: 0.9746 - accuracy: 0.5204 - val_loss: 0.8746 - val_accuracy: 0.5945
# Epoch 3/40
# 27/27 [==============================] - 241s 7s/step - loss: 0.9218 - accuracy: 0.5659 - val_loss: 0.8000 - val_accuracy: 0.6683
# Epoch 4/40
# 27/27 [==============================] - 289s 9s/step - loss: 0.8757 - accuracy: 0.6185 - val_loss: 0.7637 - val_accuracy: 0.7218
# Epoch 5/40
# 27/27 [==============================] - 250s 7s/step - loss: 0.7853 - accuracy: 0.6950 - val_loss: 0.6068 - val_accuracy: 0.8205
# Epoch 6/40
# 27/27 [==============================] - 243s 7s/step - loss: 0.6337 - accuracy: 0.7628 - val_loss: 0.4817 - val_accuracy: 0.8288
# Epoch 7/40
# 27/27 [==============================] - 402s 13s/step - loss: 0.5621 - accuracy: 0.7848 - val_loss: 0.3776 - val_accuracy: 0.8549
# Epoch 8/40
# 27/27 [==============================] - 245s 7s/step - loss: 0.4916 - accuracy: 0.8064 - val_loss: 0.4293 - val_accuracy: 0.8442
# Epoch 9/40
# 27/27 [==============================] - 250s 7s/step - loss: 0.4631 - accuracy: 0.8184 - val_loss: 0.4081 - val_accuracy: 0.8157
# Epoch 10/40
# 27/27 [==============================] - 249s 7s/step - loss: 0.4398 - accuracy: 0.8268 - val_loss: 0.4140 - val_accuracy: 0.8383
# Epoch 11/40
# 27/27 [==============================] - 308s 10s/step - loss: 0.4578 - accuracy: 0.8190 - val_loss: 0.3061 - val_accuracy: 0.8835
# Epoch 12/40
# 27/27 [==============================] - 271s 8s/step - loss: 0.4210 - accuracy: 0.8334 - val_loss: 0.3315 - val_accuracy: 0.8835
# Epoch 13/40
# 27/27 [==============================] - 297s 9s/step - loss: 0.3856 - accuracy: 0.8474 - val_loss: 0.2585 - val_accuracy: 0.9061
# Epoch 14/40
# 27/27 [==============================] - 295s 9s/step - loss: 0.3911 - accuracy: 0.8464 - val_loss: 0.2737 - val_accuracy: 0.8954
# Epoch 15/40
# 27/27 [==============================] - 249s 7s/step - loss: 0.3534 - accuracy: 0.8650 - val_loss: 0.2628 - val_accuracy: 0.9001
# Epoch 16/40
# 27/27 [==============================] - 247s 7s/step - loss: 0.3380 - accuracy: 0.8690 - val_loss: 0.3226 - val_accuracy: 0.8775
# Epoch 17/40
# 27/27 [==============================] - 249s 7s/step - loss: 0.3251 - accuracy: 0.8755 - val_loss: 0.2465 - val_accuracy: 0.9132
# Epoch 18/40
# 27/27 [==============================] - 17696s 678s/step - loss: 0.3031 - accuracy: 0.8827 - val_loss: 0.2770 - val_accuracy: 0.8966
# Epoch 19/40
# 27/27 [==============================] - 932s 29s/step - loss: 0.3167 - accuracy: 0.8786 - val_loss: 0.2182 - val_accuracy: 0.9358
# Epoch 20/40
# 27/27 [==============================] - 920s 29s/step - loss: 0.3120 - accuracy: 0.8796 - val_loss: 0.2144 - val_accuracy: 0.9334
# Epoch 21/40
# 27/27 [==============================] - 801s 24s/step - loss: 0.2871 - accuracy: 0.8904 - val_loss: 0.2112 - val_accuracy: 0.9310
# Epoch 22/40
# 27/27 [==============================] - 637s 16s/step - loss: 0.2863 - accuracy: 0.8940 - val_loss: 0.3356 - val_accuracy: 0.8656
# Epoch 23/40
# 27/27 [==============================] - 540s 16s/step - loss: 0.2812 - accuracy: 0.8907 - val_loss: 0.1887 - val_accuracy: 0.9144
# Epoch 24/40
# 27/27 [==============================] - 546s 17s/step - loss: 0.2644 - accuracy: 0.9031 - val_loss: 0.2224 - val_accuracy: 0.9239
# Epoch 25/40
# 27/27 [==============================] - 465s 14s/step - loss: 0.2826 - accuracy: 0.8918 - val_loss: 0.1875 - val_accuracy: 0.9227
# Epoch 26/40
# 27/27 [==============================] - 1802s 65s/step - loss: 0.2601 - accuracy: 0.9026 - val_loss: 0.2108 - val_accuracy: 0.9358
# Epoch 27/40
# 27/27 [==============================] - 532s 15s/step - loss: 0.2416 - accuracy: 0.9109 - val_loss: 0.2043 - val_accuracy: 0.9263
# Epoch 28/40
# 27/27 [==============================] - 535s 14s/step - loss: 0.2311 - accuracy: 0.9133 - val_loss: 0.1876 - val_accuracy: 0.9358
# Epoch 29/40
# 27/27 [==============================] - 542s 17s/step - loss: 0.2634 - accuracy: 0.9023 - val_loss: 0.1997 - val_accuracy: 0.9346
# Epoch 30/40
# 27/27 [==============================] - 555s 17s/step - loss: 0.2453 - accuracy: 0.9077 - val_loss: 0.1737 - val_accuracy: 0.9382
# Epoch 31/40
# 27/27 [==============================] - 569s 18s/step - loss: 0.2227 - accuracy: 0.9171 - val_loss: 0.2042 - val_accuracy: 0.9215
# Epoch 32/40
# 27/27 [==============================] - 524s 16s/step - loss: 0.2165 - accuracy: 0.9195 - val_loss: 0.2626 - val_accuracy: 0.8882
# Epoch 33/40
# 27/27 [==============================] - 470s 14s/step - loss: 0.2016 - accuracy: 0.9245 - val_loss: 0.1493 - val_accuracy: 0.9489
# Epoch 34/40
# 27/27 [==============================] - 480s 15s/step - loss: 0.2173 - accuracy: 0.9254 - val_loss: 0.1760 - val_accuracy: 0.9417
# Epoch 35/40
# 27/27 [==============================] - 467s 14s/step - loss: 0.2195 - accuracy: 0.9230 - val_loss: 0.1609 - val_accuracy: 0.9405
# Epoch 36/40
# 27/27 [==============================] - 469s 14s/step - loss: 0.1955 - accuracy: 0.9322 - val_loss: 0.1379 - val_accuracy: 0.9560
# Epoch 37/40
# 27/27 [==============================] - 466s 14s/step - loss: 0.1939 - accuracy: 0.9325 - val_loss: 0.1313 - val_accuracy: 0.9524
# Epoch 38/40
# 27/27 [==============================] - 503s 15s/step - loss: 0.1816 - accuracy: 0.9362 - val_loss: 0.2094 - val_accuracy: 0.9156
# Epoch 39/40
# 27/27 [==============================] - 492s 15s/step - loss: 0.1855 - accuracy: 0.9324 - val_loss: 0.1236 - val_accuracy: 0.9548
# Epoch 40/40
# 27/27 [==============================] - 484s 15s/step - loss: 0.1875 - accuracy: 0.9337 - val_loss: 0.1287 - val_accuracy: 0.9572
# Test loss: 0.13373681902885437
# Test accuracy: 0.95961993932724

# %% [markdown]
# # Model Evalutation

# %%
pd.DataFrame(history.history).to_csv("hist.csv", index=False)

plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
model = tf.keras.models.load_model('./model.hdf5')

y_pred = []
y_true = []

for image_batch, label_batch in test_ds:
    y_true.append(label_batch)
    preds = model.predict(image_batch)
    y_pred.append(np.argmax(preds, axis = - 1))

correct_labels = np.argmax(tf.concat([item for item in y_true], axis = 0), axis=1)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

cm = confusion_matrix(correct_labels, predicted_labels)
print("Broccoli Precision: ", cm[0][0] / cm[0].sum())
print("Broccoli Recall : ", cm[0][0] / cm.T[0].sum())
print()
print("Cauliflower Precision: ", cm[1][1] / cm[1].sum())
print("Cauliflower Recall: ", cm[1][1] / cm.T[1].sum())
print()
print("Unknown Precision: ", cm[2][2] / cm[2].sum())
print("Unknown Recall: ", cm[2][2] / cm.T[2].sum())

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(ax=ax)
plt.title('Confusion Matrix: Broccoli vs Cauliflower vs Unknown')
plt.tight_layout()
plt.show()
# Out:
# 8/8 [==============================] - 3s 401ms/step
# 8/8 [==============================] - 3s 400ms/step
# 8/8 [==============================] - 3s 405ms/step
# 3/3 [==============================] - 1s 266ms/step
# Broccoli Precision:  0.954983922829582
# Broccoli Recall :  0.9834437086092715
#
# Cauliflower Precision:  0.9832775919732442
# Cauliflower Recall:  0.9576547231270358
#
# Unknown Precision:  0.9353448275862069
# Unknown Recall:  0.9313304721030042
