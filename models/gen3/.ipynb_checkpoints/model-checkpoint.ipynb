# %% [markdown]
# # Import Libraries

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img, img_to_array

tf.config.set_visible_devices([], 'GPU')

# %% [markdown]
# # Exploratory Data Analysis

# %%
ROOT = "../../dataset_nounknown/"
SEED = 88
IMG_SIZE = (150, 150)    # load at original size first
BATCH_SIZE = 128
LABEL_MODE = "categorical" # one‑hot labels straight away
AUTOTUNE = tf.data.AUTOTUNE

label_map={
    "broccoli":[1,0],
    "cauliflower":[0,1],
    "unknown":[0,0]
}
classes=["broccoli", "cauliflower", "unknown"]
splits=["test", "train", "validate"]
def data_generator(split):
    for class_name in label_map.keys():
        class_dir = os.path.join(ROOT, split, class_name)
        print(class_name)
        for fname in os.listdir(class_dir):
            img_path = os.path.join(class_dir, fname)
            
            yield img_path, label_map[class_name]


def process(img_path, label):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)
    return img, label


train_ds_pre = tf.data.Dataset.from_generator(
    lambda: data_generator("train"),
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(2,), dtype=tf.float32)
    )
)
train_ds_pre = train_ds_pre.map(process, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).shuffle(1000,SEED)

val_ds_pre = tf.data.Dataset.from_generator(
    (lambda: data_generator("validate")),
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(2,), dtype=tf.float32)
    )
)
val_ds_pre = val_ds_pre.map(process, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).shuffle(1000,SEED)

test_ds_pre = tf.data.Dataset.from_generator(
    (lambda: data_generator("test")),
    output_signature=(
        tf.TensorSpec(shape=(), dtype=tf.string),
        tf.TensorSpec(shape=(2,), dtype=tf.float32)
    )
)
test_ds_pre = test_ds_pre.map(process, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).shuffle(1000,SEED)

# %%
def count_images(split):
    return {cls: len(os.listdir(f"{ROOT}{split}/{cls}/"))
            for cls in classes}

df_counts = pd.DataFrame({s: count_images(s) for s in splits})

table_df = df_counts.T
table_df["splits total"] = table_df.sum(1)
table_df.loc["img total"] = table_df.sum(0)

display(table_df)  # Jupyter table

ax = df_counts.plot.bar(stacked=True, figsize=(8,3))
ax.set_title("Class distribution across splits")
ax.set_ylabel("Image count")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
#            broccoli  cauliflower  unknown  splits total
# test           1090         1068      306          2464
# train          3355         3163     1782          8300
# validate        493          471      234          1198
# img total      4938         4702     2322         11962

# %%
plt.figure(figsize=(6,6))
for images, labels in train_ds_pre.take(1):
    for i in range(16):
        ax = plt.subplot(4,4,i+1)
        plt.imshow((images[i].numpy()).astype("uint8"))
        innertext="unknown"
        if (labels[i][1]):
            innertext="cauliflour"
        elif (labels[i][0]):
            innertext="broccoli"
        
        plt.title(innertext, fontsize=7)
        plt.axis("off")
plt.suptitle("Random train samples", y=0.92)
plt.tight_layout()
plt.show()
# Out:
# broccoli
# cauliflower
# 2025-07-14 12:41:51.787064: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:180: Filling up shuffle buffer (this may take a while): 36 of 1000
# unknown
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# 2025-07-14 12:42:00.624528: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.

# %% [markdown]
# # Data Preprocessing

# %%
TARGET_SIZE = 150

resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(TARGET_SIZE, TARGET_SIZE),
    layers.Rescaling(1./255)
])

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomZoom((0.3), 0.3),
])

AUTOTUNE = tf.data.AUTOTUNE

def prepare(ds, shuffle=False, augment=False):
    # Resize and rescale all datasets.
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y), 
                num_parallel_calls=AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(1000)

    # Use data augmentation only on the training set.
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    # Use buffered prefetching on all datasets.
    return ds

train_ds = prepare(train_ds_pre, shuffle=True, augment=True)
val_ds = prepare(val_ds_pre)
test_ds = prepare(test_ds_pre)
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds=val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
plt.figure(figsize=(3,3))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow((images[i].numpy() * 255).astype("uint8"))
        innertext="unknown"
        if (labels[i][1]):
            innertext="cauliflour"
        elif (labels[i][0]):
            innertext="broccoli"
        plt.title(innertext, fontsize=7)
        plt.axis("off")

plt.suptitle("Random train samples", y=0.92)
plt.tight_layout()
plt.show()
# Out:
# broccoli
# cauliflower
# 2025-07-14 12:42:11.436075: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:180: Filling up shuffle buffer (this may take a while): 37 of 1000
# unknown
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# Invalid SOS parameters for sequential JPEG
# 2025-07-14 12:42:19.493990: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# 2025-07-14 12:42:19.926525: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# 2025-07-14 12:42:22.142124: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# 2025-07-14 12:42:22.142206: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 34561024 bytes after encountering the first element of size 34561024 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2025-07-14 12:42:22.142239: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 34561024 bytes after encountering the first element of size 34561024 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size

# %% [markdown]
# # Model building

# %%
num_classes = 2

model = keras.Sequential()

model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(*IMG_SIZE, 3)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.4))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(2, activation='sigmoid'))  # 2 outputs for multi-label
model.summary()

Optimizer = optimizers.Adam(0.001)
model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=Optimizer,
    metrics=[
        'binary_accuracy',       # Good general multi-label check
        Precision(name='precision'),
        Recall(name='recall')
    ]
)
# Out:
# /home/me/anaconda3/envs/HELP/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_38 (Conv2D)              │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 150, 150, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 75, 75, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 37, 37, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 128)            │     5,308,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,598,114 (21.36 MB)
#  Trainable params: 5,596,962 (21.35 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(
    train_ds,
    epochs=25,
    verbose=1,
    batch_size=BATCH_SIZE,
    validation_data = val_ds
)

score = model.evaluate(test_ds, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


model.save_weights('model.weights.h5')
tf.keras.models.save_model(model,'model.keras')
# Out:
# Epoch 1/25
#      65/Unknown 190s 3s/step - binary_accuracy: 0.4991 - loss: 0.8962 - precision: 0.4135 - recall: 0.4874
# /home/me/anaconda3/envs/HELP/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - binary_accuracy: 0.4992 - loss: 0.8952 - precision: 0.4132 - recall: 0.4869 - val_binary_accuracy: 0.5092 - val_loss: 0.9085 - val_precision: 0.4115 - val_recall: 0.5114
# Epoch 2/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - binary_accuracy: 0.5468 - loss: 0.7655 - precision: 0.3440 - recall: 0.3252 - val_binary_accuracy: 0.5952 - val_loss: 0.6865 - val_precision: 0.1250 - val_recall: 0.0010
# Epoch 3/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - binary_accuracy: 0.5408 - loss: 0.7683 - precision: 0.4155 - recall: 0.2940 - val_binary_accuracy: 0.5213 - val_loss: 0.8105 - val_precision: 0.2660 - val_recall: 0.1079
# Epoch 4/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - binary_accuracy: 0.5309 - loss: 0.7640 - precision: 0.4066 - recall: 0.3213 - val_binary_accuracy: 0.5710 - val_loss: 0.6816 - val_precision: 0.3118 - val_recall: 0.0550
# Epoch 5/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - binary_accuracy: 0.5694 - loss: 0.7283 - precision: 0.3982 - recall: 0.2344 - val_binary_accuracy: 0.5947 - val_loss: 0.6763 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - binary_accuracy: 0.5601 - loss: 0.7210 - precision: 0.4383 - recall: 0.1971 - val_binary_accuracy: 0.5952 - val_loss: 0.6812 - val_precision: 0.1250 - val_recall: 0.0010
# Epoch 7/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - binary_accuracy: 0.5541 - loss: 0.7176 - precision: 0.4414 - recall: 0.1624 - val_binary_accuracy: 0.5952 - val_loss: 0.6710 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - binary_accuracy: 0.5766 - loss: 0.7049 - precision: 0.4316 - recall: 0.1392 - val_binary_accuracy: 0.6185 - val_loss: 0.6654 - val_precision: 0.9464 - val_recall: 0.0550
# Epoch 9/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - binary_accuracy: 0.6025 - loss: 0.6901 - precision: 0.3404 - recall: 0.0783 - val_binary_accuracy: 0.5956 - val_loss: 0.6658 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - binary_accuracy: 0.5992 - loss: 0.6885 - precision: 0.4380 - recall: 0.0719 - val_binary_accuracy: 0.6023 - val_loss: 0.6608 - val_precision: 0.7200 - val_recall: 0.0187
# Epoch 11/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - binary_accuracy: 0.6105 - loss: 0.6847 - precision: 0.4202 - recall: 0.0617 - val_binary_accuracy: 0.5956 - val_loss: 0.6665 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - binary_accuracy: 0.5715 - loss: 0.6951 - precision: 0.4364 - recall: 0.0528 - val_binary_accuracy: 0.5918 - val_loss: 0.6781 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 191s 3s/step - binary_accuracy: 0.5834 - loss: 0.6892 - precision: 0.4363 - recall: 0.0431 - val_binary_accuracy: 0.5918 - val_loss: 0.6724 - val_precision: 0.2308 - val_recall: 0.0062
# Epoch 14/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - binary_accuracy: 0.5959 - loss: 0.6792 - precision: 0.3726 - recall: 0.0358 - val_binary_accuracy: 0.5956 - val_loss: 0.6647 - val_precision: 0.2222 - val_recall: 0.0021
# Epoch 15/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 199s 3s/step - binary_accuracy: 0.6161 - loss: 0.6766 - precision: 0.3818 - recall: 0.0360 - val_binary_accuracy: 0.5956 - val_loss: 0.6622 - val_precision: 0.3684 - val_recall: 0.0073
# Epoch 16/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - binary_accuracy: 0.5916 - loss: 0.6834 - precision: 0.4266 - recall: 0.0313 - val_binary_accuracy: 0.6023 - val_loss: 0.6720 - val_precision: 0.6774 - val_recall: 0.0218
# Epoch 17/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - binary_accuracy: 0.5777 - loss: 0.6898 - precision: 0.4276 - recall: 0.0304 - val_binary_accuracy: 0.5952 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - binary_accuracy: 0.6167 - loss: 0.6737 - precision: 0.4045 - recall: 0.0310 - val_binary_accuracy: 0.5968 - val_loss: 0.6636 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - binary_accuracy: 0.5883 - loss: 0.6838 - precision: 0.4395 - recall: 0.0317 - val_binary_accuracy: 0.5977 - val_loss: 0.6641 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 195s 3s/step - binary_accuracy: 0.6481 - loss: 0.6596 - precision: 0.3584 - recall: 0.0230 - val_binary_accuracy: 0.5977 - val_loss: 0.6690 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - binary_accuracy: 0.6183 - loss: 0.6685 - precision: 0.4069 - recall: 0.0394 - val_binary_accuracy: 0.5972 - val_loss: 0.6572 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - binary_accuracy: 0.6377 - loss: 0.6638 - precision: 0.3860 - recall: 0.0363 - val_binary_accuracy: 0.5977 - val_loss: 0.6668 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - binary_accuracy: 0.6054 - loss: 0.6772 - precision: 0.3886 - recall: 0.0299 - val_binary_accuracy: 0.5977 - val_loss: 0.6680 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - binary_accuracy: 0.6004 - loss: 0.6763 - precision: 0.4190 - recall: 0.0327 - val_binary_accuracy: 0.5977 - val_loss: 0.6691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - binary_accuracy: 0.5858 - loss: 0.6832 - precision: 0.4574 - recall: 0.0349 - val_binary_accuracy: 0.5977 - val_loss: 0.6588 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# broccoli
# cauliflower
# unknown
# Invalid SOS parameters for sequential JPEG
# Test loss: 0.6703474521636963
# Test accuracy: 0.5620941519737244

# %% [markdown]
# # Model Evalutation

# %%
pd.DataFrame(history.history).to_csv("hist.csv", index=False)

plt.plot(history.history['binary_accuracy'], label='train acc')
plt.plot(history.history['val_binary_accuracy'], label='val acc')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
